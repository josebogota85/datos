# %% [markdown]
# Ahora lo que haremos es realizar un web scripting de una página de verdad

# %%
#Lo primero es importar request y BeatifulSoup
import requests #importamos request
from bs4 import BeautifulSoup #importamos BeatifulSoup

# %%
pagina=requests.get("https://leadacademy.com.co/").text #Generamos el requerimiento
soup=BeautifulSoup(pagina, "html.parser") #Acá lo que estamos haciendo es crear el objeto BeatifulSoup
todo=soup.find_all() #Acá traemos todo lo que le diga al objeto soup, sin embargo, es mejor traer una etiqueta especifica
#print(todo) #Acá imprimimos todo lo que trajimos
print(soup.prettify()) #Esta impresión es mejor por que me muestra todo como un texto de página web
# Out:
# <!DOCTYPE html>
# <html lang="es">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="https://leadacademy.com.co/xmlrpc.php" rel="pingback"/>
#   <script type="text/javascript">
#    document.documentElement.className = 'js';
#   </script>
#   <script>
#    var et_site_url='https://leadacademy.com.co';var et_post_id='9';function et_core_page_resource_fallback(a,b){"undefined"===typeof b&&(b=a.sheet.cssRules&&0===a.sheet.cssRules.length);b&&(a.onerror=null,a.onload=null,a.href?a.href=et_site_url+"/?et_core_page_resource="+a.id+et_post_id:a.src&&(a.src=et_site_url+"/?et_core_page_resource="+a.id+et_post_id))}
#   </script>
#   <title>
#    LEADACADEMY | HIGHER EDUCATION INSTITUTE
#   </title>
#   <meta content="max-image-preview:large" name="robots">
#    <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
#    <link href="//s.w.org" rel="dns-prefetch"/>
# ...
