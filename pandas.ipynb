# %% [markdown]
# <h1>Pandas</h1>
# <h2>Ahora si que empiece lo lindo, por fin vamos a usar pandas, tengo muchas ancias de empezar con toda</h2>

# %%
import pandas #Así se importa pandas, pero antes de importarla debemos estar seguros de haberla instqalado en la terminal o consola con pip install pandas
#Empecemos importando un archivo csv
archivo_csv="/Users/joseluisrinconortiz/Downloads/Wine_Quality_Data2.csv" #Lo primero que hacemos es asignarle a una variable la ruta del archivo CSV que queremos llenar
lectura_CSV=pandas.read_csv(archivo_csv) #luego en una segunda variable, guardamos lo que se leyo en el archivo, usando el metodo read_csv (archivo "primera variable") 
lectura_CSV.head() # mostramos los cinco primeros registros del archivo de datos
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# 2      9.8        5   red
# 3      9.8        6   red
# 4      9.4        5   red

# %%
import pandas
#Ahora carguemos un archivo excel, parece que es similar
archivo_excel="/Users/joseluisrinconortiz/Downloads/Todo_BDS.xlsx" #Taemos la ruta y la guardamos en una variable
lectura_excel=pandas.read_excel(archivo_excel) #Ahora en otra variable guardamos lo que leemos en el archivo que traemos
lectura_excel.head() #Por último muestro los cinco primeros registros del archivo
#Para realizar este ejercicio, tuve que instalar en la consola un complementos (pip installopenpyxl) super importante para que funcione
# Out:
#              Nombre completo     Año       ID  \
# 0          Jose Martín Jerez  2022.0  28558.0
# 1               Martin Badia  2022.0  10921.0
# 2     Paula Soledad Pallares  2022.0  11030.0
# 3  Ezequiel Alfonso Alvarado  2022.0  13333.0
# 4            Laura Benedetti  2022.0  10789.0
#
#                                   Mail       País  \
# 0         jose.jerez@pharmadorf.com.ar  Argentina
# 1       martin.badia@pharmadorf.com.ar  Argentina
# 2     paula.pallares@pharmadorf.com.ar  Argentina
# 3  ezequiel.alvarado@pharmadorf.com.ar  Argentina
# 4    laura.benedetti@pharmadorf.com.ar  Argentina
#
#                          Cargo           Linea        Jefe inmediato cerrado  \
# 0  Agente de propaganda médica           Mixto  Jose Ignacio Delgado      OK
# 1  Agente de propaganda médica       Cronicos   Jose Ignacio Delgado      OK
# 2  Agente de propaganda médica       Cronicos   Jose Ignacio Delgado      OK
# 3  Agente de propaganda médica  Salud Femenina  Jose Ignacio Delgado      OK
# 4  Agente de propaganda médica  Salud Femenina  Jose Ignacio Delgado      OK
#
#    estado  ... Nota 3 noviembre Nota 4 noviembre Nivela 1 noviembre  \
# 0  activo  ...              NaN          98.3325                NaN
# 1  activo  ...              NaN               95                NaN
# 2  activo  ...              NaN               95                NaN
# 3  activo  ...              NaN               90                NaN
# 4  activo  ...              NaN               90                NaN
#
#    Nivela 2 noviembre Tema1 noviembre Tema2 noviembre definitiva11     mes 11  \
# 0                 NaN             NaN             NaN     96.41625  noviembre
# 1                 NaN             NaN             NaN         97.5  noviembre
# 2                 NaN             NaN             NaN           90  noviembre
# 3                 NaN             NaN             NaN        88.75  noviembre
# 4                 NaN             NaN             NaN         94.5  noviembre
#
#    promedio_total Column53
# 0       70.479375      NaN
# 1       97.968750      NaN
# 2       96.250000      NaN
# 3       94.812500      NaN
# 4       81.781250      NaN
#
# [5 rows x 61 columns]

# %%
#Desde un diccionario podemos crear DATAFRAMES, los dataframe son organizaciones de datos en columnas y filas, veamos como pandas los hace
equipos={"nombres":["junior", "america", "Santafe", "millonarios", "caldas"],"copas":["9","13","10","14","2"],"Capital":["Barranquilla", "Cali", "Bogotá", "Bogotá", "Manizales"]} #Primero defino un diccionario
equipos_arreglados=pandas.DataFrame(equipos)  #Después de teer definidos los diccionarios los convierto en DataFramen con el metodo
equipos_arreglados.head() #Ahora muestro los primeros cinco registros

#Ojo las llaves de los diccionarios son los encabezados de las columnas y los calores de los diccionarios son los registros
# Out:
#        nombres copas       Capital
# 0       junior     9  Barranquilla
# 1      america    13          Cali
# 2      Santafe    10        Bogotá
# 3  millonarios    14        Bogotá
# 4       caldas     2     Manizales

# %%
#Podemos crear un DATAFRAME de solo una columna desde otro DATAFRAME, veamos el ejemplo
aislada=lectura_CSV[["Capital"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 2
#       1 #Podemos crear un DATAFRAME de solo una columna desde otro DATAFRAME, veamos el ejemplo
# ----> 2 aislada=lectura_CSV[["Capital"]]
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    <a href='file:///Users/joseluisrinconortiz/miniconda3/lib/python3.10/site-packages/pandas/core/frame.py?line=3810'>3811</a>     if is_iterator(key):
#    <a href='file:///Users/joseluisrinconortiz/miniconda3/lib/python3.10/site-packages/pandas/core/frame.py?line=3811'>3812</a>         key = list(key)
# -> <a href='file:///Users/joseluisrinconortiz/miniconda3/lib/python3.10/site-packages/pandas/core/frame.py?line=3812'>3813</a>     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    <a href='file:///Users/joseluisrinconortiz/miniconda3/lib/python3.10/site-packages/pandas/core/frame.py?line=3814'>3815</a> # take() does not accept boolean indexers
#    <a href='file:///Users/joseluisrinconortiz/miniconda3/lib/python3.10/site-packages/pandas/core/frame.py?line=3815'>3816</a> if getattr(indexer, "dtype", None) == bool:
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    <a href='file:///Users/joseluisrinconortiz/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=6066'>6067</a> else:
#    <a href='file:///Users/joseluisrinconortiz/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=6067'>6068</a>     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> <a href='file:///Users/joseluisrinconortiz/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=6069'>6070</a> self._raise_if_missing(keyarr, indexer, axis_name)
#    <a href='file:///Users/joseluisrinconortiz/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=6071'>6072</a> keyarr = self.take(indexer)
#    <a href='file:///Users/joseluisrinconortiz/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=6072'>6073</a> if isinstance(key, Index):
#    <a href='file:///Users/joseluisrinconortiz/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=6073'>6074</a>     # GH 42790 - Preserve name from an Index
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    <a href='file:///Users/joseluisrinconortiz/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=6127'>6128</a>     if use_interval_msg:
#    <a href='file:///Users/joseluisrinconortiz/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=6128'>6129</a>         key = list(key)
# -> <a href='file:///Users/joseluisrinconortiz/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=6129'>6130</a>     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    <a href='file:///Users/joseluisrinconortiz/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=6131'>6132</a> not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    <a href='file:///Users/joseluisrinconortiz/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=6132'>6133</a> raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Capital'], dtype='object')] are in the [columns]"
